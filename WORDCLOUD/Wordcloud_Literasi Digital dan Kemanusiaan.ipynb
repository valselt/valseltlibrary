# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('youtube.csv')

# %%
df.head()
# Out:
#       Video ID                                              Title  \
# 0  -l4sA5x5JRc              🔴 [ LIVE ] Mengenal UNNES Lebih Dekat
# 1  Et91n1lAiK4  🔴 [ LIVE ] Kuliah Umum Overcoming Economic and...
# 2  byznjlu1zLQ  UNNES TV - Titik Lokasi Seleksi Ujian CASN 202...
# 3  CEPlxX2CebY  UNNES TV - A walk-through time: Austria - Indo...
# 4  5WKXggGHBDs  UNNES TV - Kunjungan Akademik Universitas Khai...
#
#                                          Description  \
# 0  🏫 YouTube playlist\n- (BAJA ) Belajar apa jadi...
# 1  Informasi Pendaftaran Mahasiswa Baru\n• https:...
# 2  Informasi lebih lanjut https://unnes.ac.id\n#U...
# 3  Dr. Weichart joins us to share her experience ...
# 4  Informasi lebih lanjut https://unnes.ac.id\nDa...
#
#                                            URL          Published At  \
# 0  https://www.youtube.com/watch?v=-l4sA5x5JRc  2024-10-24T14:09:26Z
# 1  https://www.youtube.com/watch?v=Et91n1lAiK4  2024-10-23T17:55:24Z
# 2  https://www.youtube.com/watch?v=byznjlu1zLQ  2024-10-21T08:33:50Z
# 3  https://www.youtube.com/watch?v=CEPlxX2CebY  2024-10-17T01:16:38Z
# 4  https://www.youtube.com/watch?v=5WKXggGHBDs  2024-10-16T10:00:06Z
#
#    View Count
# 0          40
# 1         907
# 2         282
# 3         244
# 4         100

# %%
text = ' '.join(df['Description'].dropna())

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Matikan sumbu
plt.show()
